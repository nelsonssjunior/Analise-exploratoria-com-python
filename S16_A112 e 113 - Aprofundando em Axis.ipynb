# %%
# Eixos

import pandas as pd
import numpy as np

# %%
file="..\\Curso Uni_dados_Dta_Science\\drinks.csv"
drinks = pd.read_csv(file)
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'population', 'continent'],
#       dtype='object')

# %%
drinks.head(5)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol  population continent
# 0                           0.0  34.660.000      Asia
# 1                           4.9   2.876.000    Europe
# 2                           0.7  40.061.000    Africa
# 3                          12.4  77.281.000    Europe
# 4                           5.9  28.081.000    Africa

# %%
# Apagando uma coluna temporariamente

drinks.drop('continent', axis=1).head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol  population
# 0                           0.0  34.660.000
# 1                           4.9   2.876.000
# 2                           0.7  40.061.000
# 3                          12.4  77.281.000
# 4                           5.9  28.081.000

# %%
# Sem o uso do 'inplace' a coluna retorna ao Dataframe

drinks.head(5)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol  population continent
# 0                           0.0  34.660.000      Asia
# 1                           4.9   2.876.000    Europe
# 2                           0.7  40.061.000    Africa
# 3                          12.4  77.281.000    Europe
# 4                           5.9  28.081.000    Africa

# %%
#Apagando uma linha temporariamente

drinks.drop(2, axis=0).head(5)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
#
#    total_litres_of_pure_alcohol  population      continent
# 0                           0.0  34.660.000           Asia
# 1                           4.9   2.876.000         Europe
# 3                          12.4  77.281.000         Europe
# 4                           5.9  28.081.000         Africa
# 5                           4.9      86.295  North America

# %% [markdown]
# Quando referênciamos linhas e colunas com o parâmetro axis:
#
# axis0 = linhas
# axis1 = colunas

# %%
# Calcule a média de cada um

drinks.mean()
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
# explicitando o eixo

drinks.mean(axis=0)
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
#Calculando a mpedia por linha

drinks.mean(axis=1).head()
# Out:
# 0      0.000
# 1     69.975
# 2      9.925
# 3    176.850
# 4     81.225
# dtype: float64

# %%
# 'index' é um àlias para eixo 'axis=0'

drinks.mean(axis=1).head()
# Out:
# 0      0.000
# 1     69.975
# 2      9.925
# 3    176.850
# 4     81.225
# dtype: float64

# %%
# 'columns' é um àlias para eixo ' axis=1'

drinks.mean(axis='columns').head()
# Out:
# 0      0.000
# 1     69.975
# 2      9.925
# 3    176.850
# 4     81.225
# dtype: float64

# %% [markdown]
# # Ou podemos fazer explicitando o eixo
#
# ![image.png](attachment:image.png)

# %%
file="..\\Curso Uni_dados_Dta_Science\\eixos.csv"
eixos = pd.read_csv(file)
eixos.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %% [markdown]
# O comportamento padrão da função mean() [média] é o eixo 0 - axis 0

# %%
eixos.mean()
# Out:
# A    10.0
# B     5.0
# C    10.0
# dtype: float64

# %%
eixos.mean(axis=0)
# Out:
# A    10.0
# B     5.0
# C    10.0
# dtype: float64

# %%
eixos.sum(axis=0)
# Out:
# A    30
# B    15
# C    30
# dtype: int64

# %% [markdown]
# # Trabalhando com colunas

# %%
eixos.mean(axis=1)
# Out:
# 0     6.666667
# 1     8.333333
# 2    10.000000
# dtype: float64

# %%
eixos.sum(axis=1)
# Out:
# 0    20
# 1    25
# 2    30
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Verificar tipos

drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# population                       object
# continent                        object
# dtype: object

# %%
#Utilizando o método REPLACE para alterar itens no Dataframe

A = 'RATO'
B = A.replace('R','P')
print(B)
# Out:
# PATO

# %%
# Alterando o tipo de uma série existente

#Não conseguimos converter direto 'populacao_int = drinks['population'] = int(drinks.population.str.replace('.',''))

populacao_int = drinks['population'] = drinks.population.str.replace('.','')
populacao_int.head()
# Out:
# 0    34660000
# 1     2876000
# 2    40061000
# 3    77281000
# 4    28081000
# Name: population, dtype: object

# %%
inteiros = []

for item in drinks.population:
    a = item.replace('.','')
    b = int(a)
    inteiros.append(b)

# %%
inteiros[3]
# Out:
# 77281000

# %%
type(inteiros[3])
# Out:
# int

# %%
drinks["pop_total"] = pd.Series(inteiros)

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol population continent  pop_total
# 0                           0.0   34660000      Asia   34660000
# 1                           4.9    2876000    Europe    2876000
# 2                           0.7   40061000    Africa   40061000
# 3                          12.4   77281000    Europe   77281000
# 4                           5.9   28081000    Africa   28081000

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# population                       object
# continent                        object
# pop_total                         int64
# dtype: object

# %%
new_drinks = drinks.drop('population', axis=1).head()

# %%
new_drinks
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  pop_total
# 0                           0.0      Asia   34660000
# 1                           4.9    Europe    2876000
# 2                           0.7    Africa   40061000
# 3                          12.4    Europe   77281000
# 4                           5.9    Africa   28081000

# %%
new_drinks.mean()
# Out:
# beer_servings                        115.20
# spirit_servings                       65.40
# wine_servings                         85.00
# total_litres_of_pure_alcohol           4.78
# pop_total                       36591800.00
# dtype: float64

# %%
new_drinks.describe
# Out:
# <bound method NDFrame.describe of        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  pop_total
# 0                           0.0      Asia   34660000
# 1                           4.9    Europe    2876000
# 2                           0.7    Africa   40061000
# 3                          12.4    Europe   77281000
# 4                           5.9    Africa   28081000  >
